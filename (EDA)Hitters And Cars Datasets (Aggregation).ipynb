# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Read Dataset(Hitters)

# %%
df=pd.read_csv(r"C:\Users\Aishwarya\OneDrive\Desktop\AI\9th_lcecture_25_09_2022\hitters.csv")
df.head(3)
# Out:
#             Name  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  \
# 0  Andy Allanson    293    66      1    30   29     14      1     293     66
# 1     Alan Ashby    315    81      7    24   38     39     14    3449    835
# 2    Alvin Davis    479   130     18    66   72     76      3    1624    457
#
#    ...  CRuns  CRBI  CWalks  League Division PutOuts  Assists  Errors  Salary  \
# 0  ...     30    29      14       A        E     446       33      20     NaN
# 1  ...    321   414     375       N        W     632       43      10   475.0
# 2  ...    224   266     263       A        W     880       82      14   480.0
#
#    NewLeague
# 0          A
# 1          N
# 2          A
#
# [3 rows x 21 columns]

# %% [markdown]
# # 1. find out people who have batted for more than four hundred matches

# %%
df[df.AtBat>400][["Name"]]
# Out:
#                 Name
# 2        Alvin Davis
# 3       Andre Dawson
# 5    Alfredo Griffin
# 9     Andre Thornton
# 10     Alan Trammell
# ..               ...
# 317     Willie McGee
# 318  Willie Randolph
# 319   Wayne Tolleson
# 320    Willie Upshaw
# 321    Willie Wilson
#
# [151 rows x 1 columns]

# %% [markdown]
# # 2.find out the name of player who has hit max homeruns

# %%
df.HmRun.max()
# Out:
# 40

# %%
df[df.HmRun>=40][["Name"]]
# Out:
#                Name
# 136  Jesse Barfield

# %% [markdown]
# # 3.find out league wise total number of players

# %%
df.groupby(by="League")["Name"].count()
# Out:
# League
# A    175
# N    147
# Name: Name, dtype: int64

# %%
df.League.value_counts()
# Out:
# A    175
# N    147
# Name: League, dtype: int64

# %% [markdown]
# # 4. find out division wise total amount of salary invested

# %%
df["Division"].value_counts()
# Out:
# W    165
# E    157
# Name: Division, dtype: int64

# %%
df.groupby(by="Division")["Salary"].sum()
# Out:
# Division
# E    80531.006
# W    60417.501
# Name: Salary, dtype: float64

# %%
df.Salary.sum()
# Out:
# 140948.50699999998

# %% [markdown]
# # 5. find out five most senior players.

# %%
A=df.sort_values(by="Years").tail(5)
A
# Out:
#                Name  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 306     Ted Simmons    127    32      4    14   25     12     19    8396
# 121   Graig Nettles    354    77     16    36   55     41     20    8716
# 249  Reggie Jackson    419   101     18    65   58     92     20    9528
# 302      Tony Perez    200    51      2    14   29     25     23    9778
# 236       Pete Rose    237    52      0    15   25     30     24   14053
#
#      CHits  ...  CRuns  CRBI  CWalks  League Division PutOuts  Assists  \
# 306   2402  ...   1048  1348     819       N        W     167       18
# 121   2172  ...   1172  1267    1057       N        W      83      174
# 249   2510  ...   1509  1659    1342       A        W       0        0
# 302   2732  ...   1272  1652     925       N        W     398       29
# 236   4256  ...   2165  1314    1566       N        W     523       43
#
#      Errors  Salary  NewLeague
# 306       6   500.0          N
# 121      16   200.0          N
# ...

# %%
A[["Name"]]
# Out:
#                Name
# 306     Ted Simmons
# 121   Graig Nettles
# 249  Reggie Jackson
# 302      Tony Perez
# 236       Pete Rose

# %%
df.sort_values(by=['Years'],ascending=False).head()
# Out:
#                Name  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 236       Pete Rose    237    52      0    15   25     30     24   14053
# 302      Tony Perez    200    51      2    14   29     25     23    9778
# 121   Graig Nettles    354    77     16    36   55     41     20    8716
# 249  Reggie Jackson    419   101     18    65   58     92     20    9528
# 306     Ted Simmons    127    32      4    14   25     12     19    8396
#
#      CHits  ...  CRuns  CRBI  CWalks  League Division PutOuts  Assists  \
# 236   4256  ...   2165  1314    1566       N        W     523       43
# 302   2732  ...   1272  1652     925       N        W     398       29
# 121   2172  ...   1172  1267    1057       N        W      83      174
# 249   2510  ...   1509  1659    1342       A        W       0        0
# 306   2402  ...   1048  1348     819       N        W     167       18
#
#      Errors  Salary  NewLeague
# 236       6   750.0          N
# 302       7     NaN          N
# ...

# %% [markdown]
# # 6.find out the name of player who has highest salary

# %%
df.Salary.max()
# Out:
# 2460.0

# %%
df[df.Salary==2460][["Name"]]
# Out:
#              Name
# 100  Eddie Murray

# %% [markdown]
# # 7. find the player with zero home runs

# %%
df.sort_values("HmRun")
# Out:
#                 Name  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 283       Tony Armas     16     2      0     1    0      0      2      28
# 229      Ozzie Smith    514   144      0    67   54     79      9    4739
# 236        Pete Rose    237    52      0    15   25     30     24   14053
# 239  Rafael Belliard    309    72      0    33   31     26      5     354
# 188   Kurt Stillwell    279    64      0    31   26     30      1     279
# ..               ...    ...   ...    ...   ...  ...    ...    ...     ...
# 140     Jose Canseco    600   144     33    85  117     65      2     696
# 244         Rob Deer    466   108     33    75   86     72      3     652
# 115      Gary Gaetti    596   171     34    91  108     52      6    2862
# 80      Dave Kingman    561   118     35    70   94     33     16    6677
# 136   Jesse Barfield    589   170     40   107  108     69      6    2325
#
#      CHits  ...  CRuns  CRBI  CWalks  League Division PutOuts  Assists  \
# ...

# %%
df[df["HmRun"]==0][["Name"]]
# Out:
#                 Name
# 7    Argenis Salazar
# 13      Alan Wiggins
# 36     Bobby Meacham
# 41      Bill Russell
# 52     Cliff Johnson
# 62    Curt Wilkerson
# 64        Doug Baker
# 144       Julio Cruz
# 188   Kurt Stillwell
# 197      Luis Rivera
# 217     Mike Schmidt
# 229      Ozzie Smith
# 236        Pete Rose
# 239  Rafael Belliard
# 250      Ricky Jones
# 279      Steve Jeltz
# 283       Tony Armas
# 309    Vince Coleman

# %% [markdown]
# # 8.find out division wise highest home runs

# %%
df.groupby(by="Division")["HmRun"].max()
# Out:
# Division
# E    40
# W    35
# Name: HmRun, dtype: int64

# %% [markdown]
# # 9.find name of player who has more than 100 Hits

# %%
df[df.Hits>=100][["Name"]]
# Out:
#                 Name
# 2        Alvin Davis
# 3       Andre Dawson
# 5    Alfredo Griffin
# 10     Alan Trammell
# 12     Andy VanSlyke
# ..               ...
# 317     Willie McGee
# 318  Willie Randolph
# 319   Wayne Tolleson
# 320    Willie Upshaw
# 321    Willie Wilson
#
# [156 rows x 1 columns]

# %% [markdown]
# # Read Dataset(Car)

# %%
df1=pd.read_csv(r"C:\Users\Aishwarya\OneDrive\Desktop\AI\Cars93.csv")
df1
# Out:
#     id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %% [markdown]
# # 1.find out car having highest(max) mileage in city

# %%
df1["MPG.city"].max()
# Out:
# 46

# %%
df1[df1["MPG.city"]>=46][["Manufacturer"]]
# Out:
#    Manufacturer
# 38          Geo

# %% [markdown]
# # 2.find out Manufacturer of cars having mgp in highway between 15 and 30

# %%
df1[(df1["MPG.highway"]>=15)&(df1["MPG.highway"]<=30)][["Manufacturer"]]
# Out:
#    Manufacturer
# 1         Acura
# 2          Audi
# 3          Audi
# 4           BMW
# 6         Buick
# ..          ...
# 88   Volkswagen
# 89   Volkswagen
# 90   Volkswagen
# 91        Volvo
# 92        Volvo
#
# [64 rows x 1 columns]

# %% [markdown]
# # 3.find the car with max price

# %%
df1["Max.Price"].max()
# Out:
# 80.0

# %%
df1[df1["Max.Price"]==80.0]
# Out:
#     id   Manufacturer Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 58  59  Mercedes-Benz  300E  Midsize       43.8   61.9       80.0        19
#
#     MPG.highway             AirBags  ... Passengers Length  Wheelbase  Width  \
# 58           25  Driver & Passenger  ...          5    187        110     69
#
#     Turn.circle  Rear.seat.room Luggage.room  Weight   Origin  \
# 58           37            27.0         15.0    3525  non-USA
#
#                   Make
# 58  Mercedes-Benz 300E
#
# [1 rows x 28 columns]

# %% [markdown]
# #  4.find out originwise highest mpg in city

# %%
df1.groupby(by="Origin")[["MPG.city"]].max()
# Out:
#          MPG.city
# Origin
# USA            31
# non-USA        46

# %% [markdown]
# # 5.find out originwise 8 cars with highest mpg in city

# %%
c=df1.sort_values("MPG.city").tail(8)

# %%
 c.groupby(by="Origin").tail(8)
# Out:
#     id Manufacturer    Model    Type  Min.Price  Price  Max.Price  MPG.city  \
# 39  40          Geo    Storm  Sporty       11.5   12.5       13.5        30
# 72  73      Pontiac   LeMans   Small        8.2    9.0        9.9        31
# 30  31         Ford  Festiva   Small        6.9    7.4        7.9        31
# 83  84       Toyota   Tercel   Small        7.8    9.8       11.8        32
# 79  80       Subaru    Justy   Small        7.3    8.4        9.5        33
# 82  83       Suzuki    Swift   Small        7.3    8.6       10.0        39
# 41  42        Honda    Civic   Small        8.4   12.1       15.8        42
# 38  39          Geo    Metro   Small        6.7    8.4       10.0        46
#
#     MPG.highway      AirBags  ... Passengers Length  Wheelbase  Width  \
# 39           36  Driver only  ...          4    164         97     67
# 72           41         None  ...          4    177         99     66
# 30           33         None  ...          4    141         90     63
# ...

# %% [markdown]
# # 6. find out cars with (Drivers only) Airbags and which are of Small type and mpg.city less than 15

# %%
df1.value_counts("AirBags")
# Out:
# AirBags
# Driver only           42
# None                  33
# Driver & Passenger    14
# dtype: int64

# %%
df1.value_counts("Type")
# Out:
# Type
# Midsize    22
# Small      21
# Compact    16
# Sporty     14
# Large      11
# Van         9
# dtype: int64

# %%
df1[(df1.AirBags=="Driver only")&(df1.Type=="Small")&(df1["MPG.city"]>=15)]
# Out:
#     id Manufacturer   Model   Type  Min.Price  Price  Max.Price  MPG.city  \
# 23  24        Dodge  Shadow  Small        8.4   11.3       14.2        23
# 41  42        Honda   Civic  Small        8.4   12.1       15.8        42
# 63  64       Nissan  Sentra  Small        8.7   11.8       14.9        29
# 78  79       Saturn      SL  Small        9.2   11.1       12.9        28
# 83  84       Toyota  Tercel  Small        7.8    9.8       11.8        32
#
#     MPG.highway      AirBags  ... Passengers Length  Wheelbase  Width  \
# 23           29  Driver only  ...          5    172         97     67
# 41           46  Driver only  ...          4    173        103     67
# 63           33  Driver only  ...          5    170         96     66
# 78           38  Driver only  ...          5    176        102     68
# 83           37  Driver only  ...          5    162         94     65
#
#     Turn.circle  Rear.seat.room Luggage.room  Weight   Origin           Make
# ...

# %% [markdown]
# # 7. Find out top 7 most fuel economic cars for city, show results in sorted manner based on Horsepower.¶

# %%
pd.set_option("display.max_columns",30)

# %%
df1 = df1.sort_values(by=['MPG.city'],ascending=False).head(7)
df1.sort_values(by=['Horsepower'])
# Out:
#     id Manufacturer    Model   Type  Min.Price  Price  Max.Price  MPG.city  \
# 38  39          Geo    Metro  Small        6.7    8.4       10.0        46
# 30  31         Ford  Festiva  Small        6.9    7.4        7.9        31
# 82  83       Suzuki    Swift  Small        7.3    8.6       10.0        39
# 79  80       Subaru    Justy  Small        7.3    8.4        9.5        33
# 72  73      Pontiac   LeMans  Small        8.2    9.0        9.9        31
# 83  84       Toyota   Tercel  Small        7.8    9.8       11.8        32
# 41  42        Honda    Civic  Small        8.4   12.1       15.8        42
#
#     MPG.highway      AirBags DriveTrain Cylinders  EngineSize  Horsepower  \
# 38           50         None      Front         3         1.0          55
# 30           33         None      Front         4         1.3          63
# 82           43         None      Front         3         1.3          70
# ...

# %% [markdown]
# # 8.Find out Cars having mileage of more than 15 miles in city¶

# %%
df1[df1['MPG.city']>15]
# Out:
#     id Manufacturer    Model   Type  Min.Price  Price  Max.Price  MPG.city  \
# 38  39          Geo    Metro  Small        6.7    8.4       10.0        46
# 41  42        Honda    Civic  Small        8.4   12.1       15.8        42
# 82  83       Suzuki    Swift  Small        7.3    8.6       10.0        39
# 79  80       Subaru    Justy  Small        7.3    8.4        9.5        33
# 83  84       Toyota   Tercel  Small        7.8    9.8       11.8        32
# 72  73      Pontiac   LeMans  Small        8.2    9.0        9.9        31
# 30  31         Ford  Festiva  Small        6.9    7.4        7.9        31
#
#     MPG.highway      AirBags DriveTrain Cylinders  EngineSize  Horsepower  \
# 38           50         None      Front         3         1.0          55
# 41           46  Driver only      Front         4         1.5         102
# 82           43         None      Front         3         1.3          70
# ...

# %% [markdown]
# # 9.Find out Cars with US based origin

# %%
df1[df1.Origin=="USA"]
# Out:
#     id Manufacturer    Model   Type  Min.Price  Price  Max.Price  MPG.city  \
# 72  73      Pontiac   LeMans  Small        8.2    9.0        9.9        31
# 30  31         Ford  Festiva  Small        6.9    7.4        7.9        31
#
#     MPG.highway AirBags DriveTrain Cylinders  EngineSize  Horsepower   RPM  \
# 72           41    None      Front         4         1.6          74  5600
# 30           33    None      Front         4         1.3          63  5000
#
#     Rev.per.mile Man.trans.avail  Fuel.tank.capacity  Passengers  Length  \
# 72          3130             Yes                13.2           4     177
# 30          3150             Yes                10.0           4     141
#
#     Wheelbase  Width  Turn.circle  Rear.seat.room  Luggage.room  Weight  \
# 72         99     66           35            25.5          17.0    2350
# 30         90     63           33            26.0          12.0    1845
#
#    Origin            Make
# 72    USA  Pontiac LeMans
# ...

# %% [markdown]
# # 10.Find out top 7 most economic cars for city. show results manner based on horsepower

# %%
pd.set_option("display.max_columns",30)

# %%
A=df1.sort_values(by=["MPG.city"],ascending=False).head()
A.sort_values(by=["Horsepower"])
# Out:
#     id Manufacturer   Model   Type  Min.Price  Price  Max.Price  MPG.city  \
# 38  39          Geo   Metro  Small        6.7    8.4       10.0        46
# 82  83       Suzuki   Swift  Small        7.3    8.6       10.0        39
# 79  80       Subaru   Justy  Small        7.3    8.4        9.5        33
# 83  84       Toyota  Tercel  Small        7.8    9.8       11.8        32
# 41  42        Honda   Civic  Small        8.4   12.1       15.8        42
#
#     MPG.highway      AirBags DriveTrain Cylinders  EngineSize  Horsepower  \
# 38           50         None      Front         3         1.0          55
# 82           43         None      Front         3         1.3          70
# 79           37         None        4WD         3         1.2          73
# 83           37  Driver only      Front         4         1.5          82
# 41           46  Driver only      Front         4         1.5         102
#
#      RPM  Rev.per.mile Man.trans.avail  Fuel.tank.capacity  Passengers  \
# ...
