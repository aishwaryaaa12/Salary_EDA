# %% [markdown]
# # In this project we will Visualize data with different plots

# %% [markdown]
# # Read Dataset

# %%
from warnings import filterwarnings
filterwarnings("ignore")

import pandas as pd

# %%
A = pd.read_csv(r"C:\Users\Aishwarya\OneDrive\Desktop\AI\Cars93.csv")
A.head()
# Out:
#    id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0   1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1   2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2   3         Audi       90  Compact       25.9   29.1       32.3        20
# 3   4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4   5          BMW     535i  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway             AirBags  ... Passengers Length  Wheelbase  Width  \
# 0           31                None  ...          5    177        102     68
# 1           25  Driver & Passenger  ...          5    195        115     71
# 2           26         Driver only  ...          5    180        102     67
# 3           26                 NaN  ...          6    193        106     70
# 4           30         Driver only  ...          4    186        109     69
#
# ...

# %% [markdown]
# # Univariate (Categorical)

# %% [markdown]
# ~~~ plots
#    Pie chart,
#    Bar Graph(bar chart)V,
#    H(countplot)
# ~~~

# %% [markdown]
# # Q1: Count of Different types of cars

# %%
A.Type.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Type'>

# %%
A.Type.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Q2: find out different car manufacturers

# %%
A.Manufacturer.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Manufacturer'>

# %%
A.Manufacturer.value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Q3: Group wise max car price

# %%
A.groupby(by="Type")['Price'].max().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Price'>

# %%
A.groupby(by="Type")['Price'].max().plot(kind="barh")
# Out:
# <AxesSubplot:ylabel='Type'>

# %% [markdown]
# # Univariate (Continuous)

# %% [markdown]
# ~~~  uni
#     Distribution plot(Spread of Data)
#     Histogram
# ~~~

# %%
import seaborn as sb
sb.distplot(A.Price)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
A.Price.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Subplots

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30,15))

plt.subplot(2,3,1)
sb.countplot(A.Type)

plt.subplot(2,3,2)
sb.countplot(A.Origin)

plt.subplot(2,3,3)
sb.countplot(A.AirBags)

plt.subplot(2,3,4)
sb.distplot(A.Price)

plt.subplot(2,3,5)
sb.distplot(A.Horsepower)

plt.subplot(2,3,6)
sb.distplot(A.Weight)
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %%
plt.figure(figsize=(40,70))                  # using loops
x = 1

for i in A.columns:
    if(A[i].dtypes == "object"):
        plt.subplot(10,3,x)
        sb.countplot(A[i])
        x = x + 1
    else:
        plt.subplot(10,3,x)
        sb.distplot(A[i])
        x = x + 1

# %% [markdown]
# # Scatterplot and Box plot

# %%
X = A.drop(labels=["id","Make","Model","Max.Price","Min.Price","Price"],axis=1)
Y = A[["Price"]]

# %%
import matplotlib.pyplot as plt
import seaborn as sb
plt.figure(figsize=(40,60))
a = 1
for i in X.columns:
    if(X[i].dtypes == "object"):
        plt.subplot(8,3,a)
        sb.boxplot(X[i],Y.Price)
        a = a + 1
    else:
        plt.subplot(8,3,a)
        sb.scatterplot(X[i],Y.Price)
        a = a + 1
